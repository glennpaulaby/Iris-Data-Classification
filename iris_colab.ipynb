# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("C:/Users/Glenn/Downloads/IRIS.csv")

# %%
print(data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data.size
# Out:
# 750

# %%
data.shape
# Out:
# (150, 5)

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
data.values
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'Iris-setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'Iris-setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'Iris-setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'Iris-setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'Iris-setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'Iris-setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'Iris-setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'Iris-setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'Iris-setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'Iris-setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'Iris-setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'Iris-setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'Iris-setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'Iris-setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'Iris-setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'Iris-setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'Iris-setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'Iris-setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'Iris-setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'Iris-setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'Iris-setosa'],
# ...

# %% [markdown]
# # Data Understanding

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.sepal_length.value_counts()
# Out:
# 5.0    10
# 6.3     9
# 5.1     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 6.0     6
# 5.4     6
# 5.6     6
# 6.1     6
# 6.5     5
# 4.8     5
# 6.2     4
# 5.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 7.2     3
# 5.9     3
# 4.4     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.1     1
# 7.4     1
# 7.6     1
# 7.9     1
# 4.5     1
# 7.0     1
# 5.3     1
# 7.3     1
# 4.3     1
# Name: sepal_length, dtype: int64

# %%
data.sepal_length.count()
# Out:
# 150

# %%
data['sepal_length'].count()
# Out:
# 150

# %%
data.sum()
# Out:
# sepal_length                                                876.5
# sepal_width                                                 458.1
# petal_length                                                563.8
# petal_width                                                 179.8
# species         Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# dtype: object

# %%
data['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
data['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
data['sl+sw']=data['sepal_width']+data['sepal_length']

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  sl+sw
# 0           5.1          3.5           1.4          0.2  Iris-setosa    8.6
# 1           4.9          3.0           1.4          0.2  Iris-setosa    7.9
# 2           4.7          3.2           1.3          0.2  Iris-setosa    7.9
# 3           4.6          3.1           1.5          0.2  Iris-setosa    7.7
# 4           5.0          3.6           1.4          0.2  Iris-setosa    8.6

# %% [markdown]
# # Rename

# %%
data=data.rename(columns={'xyz':'h'})
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  sl+sw
# 0           5.1          3.5           1.4          0.2  Iris-setosa    8.6
# 1           4.9          3.0           1.4          0.2  Iris-setosa    7.9
# 2           4.7          3.2           1.3          0.2  Iris-setosa    7.9
# 3           4.6          3.1           1.5          0.2  Iris-setosa    7.7
# 4           5.0          3.6           1.4          0.2  Iris-setosa    8.6

# %%
data.query('sepal_length==5.9 & sepal_width==3.0')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species  \
# 61            5.9          3.0           4.2          1.5  Iris-versicolor
# 149           5.9          3.0           5.1          1.8   Iris-virginica
#
#      sl+sw
# 61     8.9
# 149    8.9

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  sl+sw
# 0           5.1          3.5           1.4          0.2  Iris-setosa    8.6
# 1           4.9          3.0           1.4          0.2  Iris-setosa    7.9
# 2           4.7          3.2           1.3          0.2  Iris-setosa    7.9
# 3           4.6          3.1           1.5          0.2  Iris-setosa    7.7
# 4           5.0          3.6           1.4          0.2  Iris-setosa    8.6

# %% [markdown]
# # Groupby

# %%
data.groupby('sepal_length',as_index=False).sum().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           4.3          3.0           1.1          0.1
# 1           4.4          9.1           4.0          0.6
# 2           4.5          2.3           1.3          0.3
# 3           4.6         13.3           5.3          0.9
# 4           4.7          6.4           2.9          0.4

# %%
data.groupby('sepal_width',as_index=False).sum().head()
# Out:
#    sepal_width  sepal_length  petal_length  petal_width  sl+sw
# 0          2.0           5.0           3.5          1.0    7.0
# 1          2.2          18.2          13.5          4.0   24.8
# 2          2.3          21.3          13.0          3.9   30.5
# 3          2.4          15.9          10.8          3.1   23.1
# 4          2.5          46.1          36.1         12.4   66.1

# %%
data.groupby('sepal_length',as_index=False).max().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  sl+sw
# 0           4.3          3.0           1.1          0.1  Iris-setosa    7.3
# 1           4.4          3.2           1.4          0.2  Iris-setosa    7.6
# 2           4.5          2.3           1.3          0.3  Iris-setosa    6.8
# 3           4.6          3.6           1.5          0.3  Iris-setosa    8.2
# 4           4.7          3.2           1.6          0.2  Iris-setosa    7.9

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  sl+sw
# 0           5.1          3.5           1.4          0.2  Iris-setosa    8.6
# 1           4.9          3.0           1.4          0.2  Iris-setosa    7.9
# 2           4.7          3.2           1.3          0.2  Iris-setosa    7.9
# 3           4.6          3.1           1.5          0.2  Iris-setosa    7.7
# 4           5.0          3.6           1.4          0.2  Iris-setosa    8.6

# %%
data.groupby('species',as_index=False).mean().head()
# Out:
#            species  sepal_length  sepal_width  petal_length  petal_width  \
# 0      Iris-setosa         5.006        3.418         1.464        0.244
# 1  Iris-versicolor         5.936        2.770         4.260        1.326
# 2   Iris-virginica         6.588        2.974         5.552        2.026
#
#    sl+sw
# 0  8.424
# 1  8.706
# 2  9.562

# %%
data.groupby('species',as_index=False).sum()
# Out:
#            species  sepal_length  sepal_width  petal_length  petal_width
# 0      Iris-setosa         250.3        170.9          73.2         12.2
# 1  Iris-versicolor         296.8        138.5         213.0         66.3
# 2   Iris-virginica         329.4        148.7         277.6        101.3

# %%
data.groupby('species',as_index=False).max().head()
# Out:
#            species  sepal_length  sepal_width  petal_length  petal_width  \
# 0      Iris-setosa           5.8          4.4           1.9          0.6
# 1  Iris-versicolor           7.0          3.4           5.1          1.8
# 2   Iris-virginica           7.9          3.8           6.9          2.5
#
#    sl+sw
# 0   10.1
# 1   10.2
# 2   11.7

# %%
data.groupby('species',as_index=False).agg(['mean','sum','min','max'])
# Out:
#                 sepal_length                  sepal_width                   \
#                         mean    sum  min  max        mean    sum  min  max
# species
# Iris-setosa            5.006  250.3  4.3  5.8       3.418  170.9  2.3  4.4
# Iris-versicolor        5.936  296.8  4.9  7.0       2.770  138.5  2.0  3.4
# Iris-virginica         6.588  329.4  4.9  7.9       2.974  148.7  2.2  3.8
#
#                 petal_length                  petal_width                   \
#                         mean    sum  min  max        mean    sum  min  max
# species
# Iris-setosa            1.464   73.2  1.0  1.9       0.244   12.2  0.1  0.6
# Iris-versicolor        4.260  213.0  3.0  5.1       1.326   66.3  1.0  1.8
# Iris-virginica         5.552  277.6  4.5  6.9       2.026  101.3  1.4  2.5
#
#                  sl+sw
#                   mean    sum  min   max
# species
# Iris-setosa      8.424  421.2  6.8  10.1
# Iris-versicolor  8.706  435.3  7.0  10.2
# ...

# %%
data.groupby('species',as_index=False).agg(['mean','sum','min','max'])
# Out:
#                 sepal_length                  sepal_width                   \
#                         mean    sum  min  max        mean    sum  min  max
# species
# Iris-setosa            5.006  250.3  4.3  5.8       3.418  170.9  2.3  4.4
# Iris-versicolor        5.936  296.8  4.9  7.0       2.770  138.5  2.0  3.4
# Iris-virginica         6.588  329.4  4.9  7.9       2.974  148.7  2.2  3.8
#
#                 petal_length                  petal_width                   \
#                         mean    sum  min  max        mean    sum  min  max
# species
# Iris-setosa            1.464   73.2  1.0  1.9       0.244   12.2  0.1  0.6
# Iris-versicolor        4.260  213.0  3.0  5.1       1.326   66.3  1.0  1.8
# Iris-virginica         5.552  277.6  4.5  6.9       2.026  101.3  1.4  2.5
#
#                  sl+sw
#                   mean    sum  min   max
# species
# Iris-setosa      8.424  421.2  6.8  10.1
# Iris-versicolor  8.706  435.3  7.0  10.2
# ...

# %%
data['x']=data['sepal_length']*data['sepal_width']
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  sl+sw  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa    8.6
# 1           4.9          3.0           1.4          0.2  Iris-setosa    7.9
# 2           4.7          3.2           1.3          0.2  Iris-setosa    7.9
# 3           4.6          3.1           1.5          0.2  Iris-setosa    7.7
# 4           5.0          3.6           1.4          0.2  Iris-setosa    8.6
#
#        x
# 0  17.85
# 1  14.70
# 2  15.04
# 3  14.26
# 4  18.00

# %%
data['x']=data['sepal_length']*data['sepal_width']
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  sl+sw  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa    8.6
# 1           4.9          3.0           1.4          0.2  Iris-setosa    7.9
# 2           4.7          3.2           1.3          0.2  Iris-setosa    7.9
# 3           4.6          3.1           1.5          0.2  Iris-setosa    7.7
# 4           5.0          3.6           1.4          0.2  Iris-setosa    8.6
#
#        x
# 0  17.85
# 1  14.70
# 2  15.04
# 3  14.26
# 4  18.00

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
#  5   sl+sw         150 non-null    float64
#  6   x             150 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.3+ KB

# %%
data=data.drop(columns='x')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  sl+sw
# 0           5.1          3.5           1.4          0.2  Iris-setosa    8.6
# 1           4.9          3.0           1.4          0.2  Iris-setosa    7.9
# 2           4.7          3.2           1.3          0.2  Iris-setosa    7.9
# 3           4.6          3.1           1.5          0.2  Iris-setosa    7.7
# 4           5.0          3.6           1.4          0.2  Iris-setosa    8.6

# %%
data.groupby('species',as_index=False).agg(['mean','sum','min','max'])
# Out:
#                 sepal_length                  sepal_width                   \
#                         mean    sum  min  max        mean    sum  min  max
# species
# Iris-setosa            5.006  250.3  4.3  5.8       3.418  170.9  2.3  4.4
# Iris-versicolor        5.936  296.8  4.9  7.0       2.770  138.5  2.0  3.4
# Iris-virginica         6.588  329.4  4.9  7.9       2.974  148.7  2.2  3.8
#
#                 petal_length                  petal_width                   \
#                         mean    sum  min  max        mean    sum  min  max
# species
# Iris-setosa            1.464   73.2  1.0  1.9       0.244   12.2  0.1  0.6
# Iris-versicolor        4.260  213.0  3.0  5.1       1.326   66.3  1.0  1.8
# Iris-virginica         5.552  277.6  4.5  6.9       2.026  101.3  1.4  2.5
#
#                  sl+sw
#                   mean    sum  min   max
# species
# Iris-setosa      8.424  421.2  6.8  10.1
# Iris-versicolor  8.706  435.3  7.0  10.2
# ...

# %%
data.groupby('species',as_index=False).agg({'sepal_length':['mean','sum','min','max']})
# Out:
#            species sepal_length
#                            mean    sum  min  max
# 0      Iris-setosa        5.006  250.3  4.3  5.8
# 1  Iris-versicolor        5.936  296.8  4.9  7.0
# 2   Iris-virginica        6.588  329.4  4.9  7.9

# %%
data.groupby('species',as_index=False).min()
# Out:
#            species  sepal_length  sepal_width  petal_length  petal_width  \
# 0      Iris-setosa           4.3          2.3           1.0          0.1
# 1  Iris-versicolor           4.9          2.0           3.0          1.0
# 2   Iris-virginica           4.9          2.2           4.5          1.4
#
#    sl+sw
# 0    6.8
# 1    7.0
# 2    7.4

# %%
data.groupby(['species','sepal_width']).min()
# Out:
#                              sepal_length  petal_length  petal_width
# species         sepal_width
# Iris-setosa     2.3                   4.5           1.3          0.3
#                 2.9                   4.4           1.4          0.2
#                 3.0                   4.3           1.1          0.1
#                 3.1                   4.6           1.5          0.1
#                 3.2                   4.4           1.2          0.2
#                 3.3                   5.0           1.4          0.2
#                 3.4                   4.6           1.4          0.2
#                 3.5                   5.0           1.3          0.2
#                 3.6                   4.6           1.0          0.2
#                 3.7                   5.1           1.5          0.2
#                 3.8                   5.1           1.5          0.2
#                 3.9                   5.4           1.3          0.4
# ...

# %%
data.groupby(['sepal_width','species']).min()
# Out:
#                              sepal_length  petal_length  petal_width  sl+sw
# sepal_width species
# 2.0         Iris-versicolor           5.0           3.5          1.0    7.0
# 2.2         Iris-versicolor           6.0           4.0          1.0    8.2
#             Iris-virginica            6.0           5.0          1.5    8.2
# 2.3         Iris-setosa               4.5           1.3          0.3    6.8
#             Iris-versicolor           5.0           3.3          1.0    7.3
# 2.4         Iris-versicolor           4.9           3.3          1.0    7.3
# 2.5         Iris-versicolor           5.1           3.0          1.1    7.6
#             Iris-virginica            4.9           4.5          1.7    7.4
# 2.6         Iris-versicolor           5.5           3.5          1.0    8.1
#             Iris-virginica            6.1           5.6          1.4    8.7
# 2.7         Iris-versicolor           5.2           3.9          1.0    7.9
# ...

# %% [markdown]
# # Data Visualisation

# %%
import matplotlib.pyplot as plt
a=data['sepal_length']
b=data['sepal_width']
plt.scatter(a,b,color='green')

# %%
a=data['sepal_length']
b=data['sepal_width']
plt.bar(a,b,color='blue')
plt.xlabel('Sepal_Length',size=15)
plt.ylabel('Sepal_Width',size=15)
plt.show()

# %%
a=data['sepal_length']
b=data['petal_length']
plt.bar(a,b,color='red',alpha=0.5)
plt.title('Sepal Length vs Petal Length')
plt.show()

# %%
a=data['sepal_length']
b=data['petal_length']
plt.plot(a,b,color='yellow',alpha=1)
plt.title('Sepal Length vs Petal Length')
plt.show()

# %%
a=data['sepal_length']
plt.hist(a)
plt.show()

# %% [markdown]
# # Import necessary datasets

# %%
from sklearn import svm,datasets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
C = 1.0 # SVM regularization parameter
models = (svm.SVC(kernel='linear', C=C),
svm.LinearSVC(C=C, max_iter=10000),
svm.SVC(kernel='rbf', gamma=0.7, C=C),
svm.SVC(kernel='poly', degree=3, gamma='auto', C=C)) models = (clf.fit(X, y) for clf in models)
# Out:
#   File "<ipython-input-60-ff9896aa66b1>", line 5
#     svm.SVC(kernel='poly', degree=3, gamma='auto', C=C)) models = (clf.fit(X, y) for clf in models)
#                                                          ^
# SyntaxError: invalid syntax
